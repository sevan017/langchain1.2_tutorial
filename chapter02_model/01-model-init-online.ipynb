# %% [markdown]
# # 调用线上的大模型
#
# ## 1. 调用具体模型厂商的API
#
# ### 1.1 调用DeepSeek官网的DeepSeek模型
#
# 调用大模型涉及到三个特别重要的参数：
# base_url、model_name、api_key
#
# 举例1:将参数信息存储在.env配置文件中

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 2、模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL,
)

# 3、模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是DeepSeek，由深度求索公司创造的AI助手，能免费为你提供文本处理、文件上传、长上下文理解及联网搜索等智能服务。' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户要求用一句话介绍自己，需要简洁明了地说明身份和核心功能。我是DeepSeek，由深度求索公司开发的AI助手，可以免费提供文本处理、问题解答等服务。关键信息点包括：名称、开发方、免费属性、多文件支持、长上下文和联网搜索能力。要避免冗余，直接提炼核心服务内容。'} response_metadata={'token_usage': {'completion_tokens': 112, 'prompt_tokens': 9, 'total_tokens': 121, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 77, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '38966e0c-bd57-4c7d-beba-1591c4509315', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ef323-7634-7ee1-bc0b-43d076c6e5c9-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 9, 'output_tokens': 112, 'total_tokens': 121, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 77}}

# %% [markdown]
# 举例2：是对举例1的优化

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
# DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 2、模型的初始化，默认会读取DEEPSEEK_API_KEY DEEPSEEK_BASE_URL，创建模型时可以不写
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    # api_key=DEEPSEEK_API_KEY,
    # api_base=DEEPSEEK_BASE_URL,
)

# 3、模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是DeepSeek，由深度求索公司创造的AI助手，免费、中文友好、知识更新至2025年5月，擅长通过简洁准确的回答帮助用户解决各类问题，支持长上下文理解和文件处理。' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户让我用一句话介绍自己。这个问题很简单，就是需要我给出一个简洁全面的自我介绍。我需要涵盖我的身份、核心能力和主要特点。我是DeepSeek，由深度求索公司创造。功能上，我是文本模型，能处理问答、写作、分析等任务，还支持长上下文和文件处理。特点方面，免费、中文友好、知识更新到2025年5月。把这些元素整合成一句流畅的话，注意语气正式但保持亲切，毕竟是在介绍自己。'} response_metadata={'token_usage': {'completion_tokens': 152, 'prompt_tokens': 9, 'total_tokens': 161, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 105, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'a64acdb5-6a7e-4d17-a1bb-dd51529bdc7d', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ef328-3136-79d1-a8de-c17e01de3968-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 9, 'output_tokens': 152, 'total_tokens': 161, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 105}}

# %% [markdown]
# 举例3：演示一下参数声明在代码中（不推荐）

# %%
from langchain_deepseek import ChatDeepSeek

# 模型的初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-v4-flash",
    # api_key="", 可以写在构建函数，不推荐。容易泄露
    api_base="https://api.deepseek.com",
)

# 模型的调用
response= llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是DeepSeek，由深度求索公司创造的AI助手，可以免费帮你处理长文本、分析文件、联网搜索，随时为你解答问题！' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户让我用一句话介绍自己。这是一个非常简单的请求，需要高度概括我的核心身份和功能。我是DeepSeek，由深度求索公司创造的AI助手。我的主要特点是免费、能处理长文本、支持文件上传和联网搜索。用户可能想快速了解我能做什么，以便决定是否使用我。所以，我的回应要直接、清晰、突出关键优势，让用户一目了然。想到了可以这样组织：先说明身份和创造者，然后点明核心功能（长文本、文件、联网），最后强调免费和便捷的特性。'} response_metadata={'token_usage': {'completion_tokens': 151, 'prompt_tokens': 9, 'total_tokens': 160, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 118, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '71807737-07d0-4916-a467-ae81b37871e2', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ef329-26c7-7443-b3e6-de47b594240e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 9, 'output_tokens': 151, 'total_tokens': 160, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 118}}

# %% [markdown]
# ### 1.2 通过智谱平台获取相关的大模型
#
# 举例

# %%
from langchain_community.chat_models import ChatZhipuAI
import os

from dotenv import load_dotenv

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
# ZHPPUAI_BASE_URL = os.getenv("ZHPPUAI_BASE_URL")

# 2、模型的初始化
llm_zhipu = ChatZhipuAI(
    model="glm-5.1",
    # api_key=ZHIPUAI_API_KEY,
    # api_base=ZHPPUAI_BASE_URL,
)

# 3、模型的调用
response= llm_zhipu.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是Z.ai开发的智能助手，随时为您提供信息和帮助。' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 205, 'completion_tokens_details': {'reasoning_tokens': 191}, 'prompt_tokens': 10, 'prompt_tokens_details': {'cached_tokens': 0}, 'total_tokens': 215}, 'model_name': 'glm-5.1', 'finish_reason': 'stop'} id='lc_run--019e3a85-9629-7773-9aa2-33bc3f5fd58c-0' tool_calls=[] invalid_tool_calls=[]

# %% [markdown]
# ### 1.3 通过阿里云百炼平台获取相关的大模型
#
# 举例

# %%
from langchain_community.chat_models import ChatTongyi
from dotenv import load_dotenv

# 1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# DASHSCOPE_API_KEY = os.getenv("DASHSCOPE_API_KEY")

# 2、模型的初始化
llm_tongyi = ChatTongyi(
    model="qwen3.7-max",
    # api_key=DASHSCOPE_API_KEY,
)

# 3、模型的调用
response= llm_tongyi.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是由阿里巴巴通义实验室自主研发的大语言模型通义千问，致力于成为您真诚、专业且富有洞察力的AI思考伙伴。' additional_kwargs={'reasoning_content': '用户要求用一句话介绍我自己。\n我是通义千问（Qwen），由阿里巴巴集团通义实验室自主研发。\n\n核心要素：\n1. 名字：通义千问（Qwen）\n2. 开发者：阿里巴巴集团通义实验室\n3. 身份/能力：人工智能/大语言模型，能够协助思考、创作、编程等。\n4. 限制：一句话。\n\n草稿1：我是通义千问，由阿里巴巴通义实验室自主研发，是一个能够为您提供全方位智能辅助的大语言模型。\n草稿2：我是由阿里巴巴通义实验室自主研发的大语言模型通义千问，致力于成为您真诚、专业且富有洞察力的AI思考伙伴。\n\n草稿2更好，体现了“思考伙伴”的定位，且包含所有必要信息，语言流畅，严格是一句话。\n\n精简优化：\n我是由阿里巴巴通义实验室自主研发的大语言模型通义千问，致力于成为您真诚、专业且富有洞察力的AI思考伙伴。\n\n检查约束：\n- 一句话？是的。\n- 身份正确？是的（通义千问，阿里巴巴通义实验室）。\n- 没有提及版本号？是的。\n\n就用这个了。'} response_metadata={'model_name': 'qwen3.7-max', 'finish_reason': 'stop', 'request_id': 'af2cff68-6546-9c99-b111-c41f4ac56aac', 'token_usage': {'input_tokens': 14, 'output_tokens': 281, 'output_tokens_details': {'reasoning_tokens': 247}, 'prompt_tokens_details': {'cached_tokens': 0}, 'total_tokens': 295}} id='lc_run--019ef333-5e94-7b21-b7ce-2b8068c4ef06-0' tool_calls=[] invalid_tool_calls=[]

# %% [markdown]
# ## 2. 兼容的写法
#
# 使用ChatOpenAI
#
# 举例1：调用deepseek官网提供的大模型

# %%
from langchain_openai import ChatOpenAI

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

print(model.invoke("1 + 1 = ？"))
# Out:
# content='1 + 1 = 2' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 42, 'prompt_tokens': 11, 'total_tokens': 53, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 34, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 11}, 'model_provider': 'openai', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'd9995564-75ae-4132-af96-01978a502240', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ef335-3129-7fc1-ab83-c0042d012ac8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 11, 'output_tokens': 42, 'total_tokens': 53, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 34}}

# %% [markdown]
# 举例2：调用智谱平台的大模型

# %%
from langchain_openai import ChatOpenAI

# 加载配置文件
load_dotenv(override=True)

ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
ZHPPUAI_BASE_URL = os.getenv("ZHPPUAI_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="glm-5.1",
    api_key=ZHIPUAI_API_KEY,
    base_url=ZHPPUAI_BASE_URL,
)

print(model.invoke("1 + 1 = ？"))
# Out:
# content='1 + 1 = 2' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 150, 'prompt_tokens': 11, 'total_tokens': 161, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 141, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'glm-5.1', 'system_fingerprint': None, 'id': '20260518175735b458cc9accc44e0b', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e3a84-cfdf-7592-a6da-260d36db2844-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 11, 'output_tokens': 150, 'total_tokens': 161, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 141}}

# %% [markdown]
# ## 3. 使用中转平台
#
# ### 3.1 使用OpenRouter
#
# 举例1：调用的国内的大模型。比如Deepseek

# %%
from langchain_openrouter import ChatOpenRouter
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

# 获取大模型
model = ChatOpenRouter(
    model="deepseek/deepseek-v4-flash",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='你好！我是DeepSeek，由深度求索公司创造的AI助手，专长是处理文本、阅读链接和文件（支持图像、PDF、Word、Excel等），拥有100万token的超长上下文，完全免费使用，知识截止于2025年5月，希望用热情、细腻的方式帮你解答各种问题！有什么我可以帮你的吗？😊' additional_kwargs={'reasoning_content': '好的，用户让我用一句话介绍自己。这是一个非常简单的请求，需要简洁明了地概括我的核心身份和功能。我是DeepSeek，由深度求索公司创造，主要定位是文本处理的AI助手，核心特点包括免费、长上下文、文件处理能力和联网搜索。也需要提及我的知识截止时间，以及我热情细腻的风格。最后用一句友好的话收尾，让用户知道可以随时提问。', 'reasoning_details': [{'type': 'reasoning.text', 'text': '好的，用户让我用一句话介绍自己。这是一个非常简单的请求，需要简洁明了地概括我的核心身份和功能。我是DeepSeek，由深度求索公司创造，主要定位是文本处理的AI助手，核心特点包括免费、长上下文、文件处理能力和联网搜索。也需要提及我的知识截止时间，以及我热情细腻的风格。最后用一句友好的话收尾，让用户知道可以随时提问。', 'format': 'unknown', 'index': 0.0}]} response_metadata={'model_name': 'deepseek/deepseek-v4-flash-20260423', 'id': 'gen-1779170997-jbsr7FnqKdvEbOhc8H1p', 'created': 1779170997, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter'} id='lc_run--019e3eda-ebd7-71e2-a782-3cb0484d7743-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 166, 'total_tokens': 174, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 87}}

# %% [markdown]
# 举例2：调用国外的大模型。比如gpt

# %%
from langchain_openrouter import ChatOpenRouter
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

# OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
# OPENROUTER_API_BASE = os.getenv("OPENROUTER_API_BASE")

# 获取大模型
model = ChatOpenRouter(
    model="openai/gpt-4o-mini",
    # api_key=OPENROUTER_API_KEY,
    # base_url=OPENROUTER_API_BASE,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='我是一个智能助手，旨在提供信息、解决问题和帮助你完成各种任务。' additional_kwargs={} response_metadata={'model_name': 'openai/gpt-4o-mini', 'id': 'gen-1779164104-K5SzOU56y01w5vcDjuKz', 'created': 1779164104, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter', 'system_fingerprint': 'fp_eb37e061ec'} id='lc_run--019e3e71-c067-7fe3-a23f-3f2d9bae1da0-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 20, 'total_tokens': 33, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}}

# %% [markdown]
# ### 3.2 使用CloseAI平台
#
# 举例1：调用国内的大模型。比如deepseek

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='你好，我是DeepSeek，由深度求索公司创造的AI助手，擅长文本处理、文件分析、长上下文理解和联网搜索，完全免费使用。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 131, 'prompt_tokens': 8, 'total_tokens': 139, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 96, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': None, 'id': 'chatcmpl-334c07e2-8242-96b1-8f88-95ec90c45e12', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e3e77-6e35-7eb3-9576-854ed9581798-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 131, 'total_tokens': 139, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 96}}

# %% [markdown]
# 举例2：调用国外的大模型。比如：gpt

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = ChatOpenAI(
    model="gpt-5.4-mini",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='我是一个由 OpenAI 训练的 AI 助手，能帮你回答问题、写作、翻译、总结和提供思路。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 35, 'prompt_tokens': 12, 'total_tokens': 47, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 4, 'engine_ttft_ms': 30, 'engine_ttlt_ms': 158, 'pre_inference_ms': 70, 'service_tbt_ms': 4, 'service_ttft_ms': 167, 'service_ttlt_ms': 287, 'total_duration_ms': 225, 'user_visible_ttft_ms': 96}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-Dh6G7wk7ZpYIIg4HVBU9pZN4bJRYO', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e3e78-53aa-7560-9510-52cef6c19650-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 35, 'total_tokens': 47, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# ## 4. 使用LangChain1.x的统一方式
#
# 使用 init_chat_model()
#
# 举例1：调用DeepSeek官网的DeepSeek模型

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model = init_chat_model(
    # model="deepseek-v4-flash",
    # model_provider="deepseek",
    # 或者
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='你好，我是DeepSeek，一个免费的AI助手，拥有超长上下文处理能力（1M tokens），支持文件上传、联网搜索和语音输入，乐于为你提供专业、细腻的帮助！' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户让我用一句话介绍自己。这是一个很简单的请求，但需要概括出核心功能和定位。我是DeepSeek，由深度求索公司创造的AI助手。关键点应该包括：我是谁、能做什么、主要特点。特点方面可以突出免费、长文本处理能力、文件上传功能、联网搜索等。一句话需要简洁有力，把最重要的信息传达清楚。想到了用“免费的AI助手”作为基本定位，加上“超长上下文”这个独特卖点，以及“文件上传”和“联网搜索”这两个实用功能。这样一句话就能让用户快速了解我的价值。'} response_metadata={'token_usage': {'completion_tokens': 168, 'prompt_tokens': 8, 'total_tokens': 176, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 126, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'afb88f5f-1b16-44dd-8d42-821d4abca159', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019ef33a-5698-7cf2-b1b9-08db566c8ba8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 168, 'total_tokens': 176, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 126}}

# %% [markdown]
# 举例2：调用CloseAI平台的大模型

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="openai:deepseek-v4-flash",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 18
#      14     api_key=CLOSEAI_API_KEY,
#      15     base_url=CLOSEAI_BASE_URL,
#      16 )
#      17
# ---> 18 print(model.invoke("一句话介绍下你自己"))
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\langchain_core\language_models\chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\langchain_openai\chat_models\base.py:1487, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1480         return _construct_lc_result_from_responses_api(
#    1481             response,
#    1482             schema=original_schema_obj,
#    1483             metadata=generation_info,
#    1484             output_version=self.output_version,
#    1485         )
#    1486     else:
# -> 1487         raw_response = self.client.with_raw_response.create(**payload)
#    1488         response = raw_response.parse()
#    1489 except openai.BadRequestError as e:
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\openai\resources\chat\completions\completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1164 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1165 def create(
#    1166     self,
#    (...)   1208     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1209 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1210     validate_response_format(response_format)
# -> 1211     return self._post(
#    1212         "/chat/completions",
#    1213         body=maybe_transform(
#    1214             {
#    1215                 "messages": messages,
#    1216                 "model": model,
#    1217                 "audio": audio,
#    1218                 "frequency_penalty": frequency_penalty,
#    1219                 "function_call": function_call,
#    1220                 "functions": functions,
#    1221                 "logit_bias": logit_bias,
#    1222                 "logprobs": logprobs,
#    1223                 "max_completion_tokens": max_completion_tokens,
#    1224                 "max_tokens": max_tokens,
#    1225                 "metadata": metadata,
#    1226                 "modalities": modalities,
#    1227                 "n": n,
#    1228                 "parallel_tool_calls": parallel_tool_calls,
#    1229                 "prediction": prediction,
#    1230                 "presence_penalty": presence_penalty,
#    1231                 "prompt_cache_key": prompt_cache_key,
#    1232                 "prompt_cache_retention": prompt_cache_retention,
#    1233                 "reasoning_effort": reasoning_effort,
#    1234                 "response_format": response_format,
#    1235                 "safety_identifier": safety_identifier,
#    1236                 "seed": seed,
#    1237                 "service_tier": service_tier,
#    1238                 "stop": stop,
#    1239                 "store": store,
#    1240                 "stream": stream,
#    1241                 "stream_options": stream_options,
#    1242                 "temperature": temperature,
#    1243                 "tool_choice": tool_choice,
#    1244                 "tools": tools,
#    1245                 "top_logprobs": top_logprobs,
#    1246                 "top_p": top_p,
#    1247                 "user": user,
#    1248                 "verbosity": verbosity,
#    1249                 "web_search_options": web_search_options,
#    1250             },
#    1251             completion_create_params.CompletionCreateParamsStreaming
#    1252             if stream
#    1253             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254         ),
#    1255         options=make_request_options(
#    1256             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257         ),
#    1258         cast_to=ChatCompletion,
#    1259         stream=stream or False,
#    1260         stream_cls=Stream[ChatCompletionChunk],
#    1261     )
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\openai\_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\openai\_base_client.py:1005, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1003 response = None
#    1004 try:
# -> 1005     response = self._client.send(
#    1006         request,
#    1007         stream=stream or self._should_stream_response_body(request=request),
#    1008         **kwargs,
#    1009     )
#    1010 except httpx.TimeoutException as err:
#    1011     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#      99 except BaseException as exc:
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      76 with self._request_lock:
#      77     if self._connection is None:
# ---> 78         stream = self._connect(request)
#      80         ssl_object = stream.get_extra_info("ssl_object")
#      81         http2_negotiated = (
#      82             ssl_object is not None
#      83             and ssl_object.selected_alpn_protocol() == "h2"
#      84         )
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     116     kwargs = {
#     117         "host": self._origin.host.decode("ascii"),
#     118         "port": self._origin.port,
#    (...)    121         "socket_options": self._socket_options,
#     122     }
#     123     with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124         stream = self._network_backend.connect_tcp(**kwargs)
#     125         trace.return_value = stream
#     126 else:
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\site-packages\httpcore\_backends\sync.py:208, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
#     207 with map_exceptions(exc_map):
# --> 208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#     213     for option in socket_options:
#     214         sock.setsockopt(*option)  # pragma: no cover
#
# File D:\ProgramData\miniconda3\envs\langchain1.2\Lib\socket.py:856, in create_connection(address, timeout, source_address, all_errors)
#     854 except error as exc:
#     855     if not all_errors:
# --> 856         exceptions.clear()  # raise only the last error
#     857     exceptions.append(exc)
#     858     if sock is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# 举例3：

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="openai:gpt-5.4-mini",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL,
)

print(model.invoke("一句话介绍下你自己"))
# Out:
# content='我是一个由 OpenAI 训练的 AI 助手，能帮你回答问题、写作、翻译、总结和处理各种文本任务。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 12, 'total_tokens': 48, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 5, 'engine_ttft_ms': 33, 'engine_ttlt_ms': 209, 'pre_inference_ms': 90, 'service_tbt_ms': 5, 'service_ttft_ms': 178, 'service_ttlt_ms': 353, 'total_duration_ms': 268, 'user_visible_ttft_ms': 89}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-Dh9OSprhyTQTVVXI3NYg3F42q811m', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e3f30-2fa0-7c61-a234-fbdd9eeecb88-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 12, 'output_tokens': 36, 'total_tokens': 48, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# ## 5. 小结
#
# DeepSeek官网的DeepSeek模型：ChatDeepSeek() 、 ChatOpenAI() 、 init_chat_model()
#
# 阿里云百炼平台的DeepSeek模型：ChatTongyi() 、ChatOpenAI() 、 init_chat_model()
#
# OpenRouter平台的DeepSeek模型：ChatOpenRouter() 、 ChatOpenAI()、init_chat_model()
#
# CloseAI平台的DeepSeek模型：ChatOpenAI()、init_chat_model()
