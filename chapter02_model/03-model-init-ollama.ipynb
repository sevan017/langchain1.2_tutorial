# %% [markdown]
# # 使用本地ollama中的模型进行初始化
#
# 举例1：使用ChatOllama

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="deepseek-r1:7b",
    base_url="http://localhost:11434"
)

print(model.invoke("介绍一下你自己"))
# Out:
# content='\n\n您好！我是由中国的深度求索（DeepSeek）公司开发的智能助手DeepSeek-R1。如您有任何任何问题，我会尽我所能为您提供帮助。' additional_kwargs={} response_metadata={'model': 'deepseek-r1:7b', 'created_at': '2026-06-23T07:06:29.2899108Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6353404800, 'load_duration': 5422211100, 'prompt_eval_count': 5, 'prompt_eval_duration': 52179000, 'eval_count': 75, 'eval_duration': 867332000, 'logprobs': None, 'model_name': 'deepseek-r1:7b', 'model_provider': 'ollama'} id='lc_run--019ef34d-3155-7362-9662-ac69ac732c82-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 5, 'output_tokens': 75, 'total_tokens': 80}

# %% [markdown]
# 举例2：使用init_chat_model()

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="deepseek-r1:7b",
    model_provider="ollama",
    base_url="http://localhost:11434"
)

print(model.invoke("介绍一下你自己"))
# Out:
# content='\n\n您好！我是由中国的深度求索（DeepSeek）公司开发的智能助手DeepSeek-R1。如您有任何任何问题，我会尽我所能为您提供帮助。' additional_kwargs={} response_metadata={'model': 'deepseek-r1:7b', 'created_at': '2026-06-23T07:07:19.2577157Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1340222500, 'load_duration': 140479900, 'prompt_eval_count': 5, 'prompt_eval_duration': 312116000, 'eval_count': 75, 'eval_duration': 874666000, 'logprobs': None, 'model_name': 'deepseek-r1:7b', 'model_provider': 'ollama'} id='lc_run--019ef34e-081c-7873-98c0-6ebb3844379a-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 5, 'output_tokens': 75, 'total_tokens': 80}
